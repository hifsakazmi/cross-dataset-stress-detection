# %% [markdown]
# <a href="https://colab.research.google.com/github/hifsakazmi/cross-dataset-stress-detection/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import importlib
import shutil
import os

# Remove old clone if exists
if os.path.exists('/content/cross-dataset-stress-detection'):
    shutil.rmtree('/content/cross-dataset-stress-detection')

# !git clone https://github.com/hifsakazmi/cross-dataset-stress-detection.git
# %cd cross-dataset-stress-detection
# Out:
# Cloning into 'cross-dataset-stress-detection'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 41 (delta 8), reused 24 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 10.34 KiB | 3.45 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/cross-dataset-stress-detection

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 70.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.2 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.2 which is incompatible.
# ...

# %%
import scripts.extract_data as extract_data
importlib.reload(extract_data)

from scripts.extract_data import extract_wesad, extract_campanella, extract_nurse

DRIVE_ROOT = "/content/drive/MyDrive/stress_data"
OUTPUT = "/content/drive/MyDrive/stress_data/extracted"

extract_wesad(DRIVE_ROOT, OUTPUT)
extract_campanella(DRIVE_ROOT, OUTPUT)
extract_nurse(DRIVE_ROOT, OUTPUT)
# Out:
# Extracting WESAD...
#   Found 15 subjects
#   S10: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S11: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S13: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S14: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S15: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S16: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S17: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S2: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S3: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S4: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S5: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
#   S6: ['ACC.csv', 'EDA.csv', 'BVP.csv', 'TEMP.csv', 'IBI.csv', 'HR.csv']
# ...

# %%
from src.data_loader import load_subject

signals, rates = load_subject(
    subject_path="/content/drive/MyDrive/stress_data/extracted/campanella/subject_01"
)
for name, df in signals.items():
    print(f"{name}: {df.shape}, {df.index[0]} → {df.index[-1]}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3097/3590491665.py in <cell line: 0>()
#       1 from src.data_loader import load_subject
#       2
# ----> 3 signals, rates = load_subject(
#       4     subject_path="/content/drive/MyDrive/stress_data/extracted/campanella/subject_01"
#       5 )
#
# TypeError: load_subject() got an unexpected keyword argument 'subject_path'
